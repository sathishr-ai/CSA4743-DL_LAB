# %% [markdown]
# <a href="https://colab.research.google.com/github/sathishr-ai/CSA4743-DL_LAB/blob/main/DL_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment 1 – Confusion Matrix

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
actual=['Dog','Dog','Dog','Not Dog']
pred=['Dog','Not Dog','Dog','Not Dog']
cm=confusion_matrix(actual,pred)
sns.heatmap(cm,annot=True,fmt='g')
plt.show()

# %% [markdown]
# Experiment 2 – Two Class Confusion Matrix

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,classification_report,confusion_matrix

wine=load_wine()
data=pd.DataFrame(data=wine.data,columns=wine.feature_names)
data['Target']=wine.target
data=data[data['Target']!=2]
x=data.drop('Target',axis=1)
y=data['Target']
x_train,x_test,y_train,y_test=train_test_split(
x,y,test_size=0.3,random_state=1)
model=DecisionTreeClassifier(random_state=1)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("accuracy:",accuracy)
class_report=classification_report(
y_test,y_pred,target_names=wine.target_names[:2])
print("Classification Report:\n",class_report)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1=f1_score(y_test,y_pred)
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
conf_matrix=confusion_matrix(y_test,y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix,annot=True,fmt='d',
xticklabels=wine.target_names[:2],
yticklabels=wine.target_names[:2])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# accuracy: 0.9743589743589743
# Classification Report:
#                precision    recall  f1-score   support
#
#      class_0       1.00      0.94      0.97        17
#      class_1       0.96      1.00      0.98        22
#
#     accuracy                           0.97        39
#    macro avg       0.98      0.97      0.97        39
# weighted avg       0.98      0.97      0.97        39
#
# Precision: 0.96
# Recall: 1.00
# F1 Score: 0.98

# %% [markdown]
# Experiment 3 – Multi Class Confusion Matrix

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import *
import seaborn as sns
import matplotlib.pyplot as plt
x,y=load_digits(return_X_y=True)
x1,x2,y1,y2=train_test_split(x,y,test_size=0.25)
m=RandomForestClassifier(random_state=23)
m.fit(x1,y1)
p=m.predict(x2)
sns.heatmap(confusion_matrix(y2,p),annot=True,fmt='g')
plt.show()
print("Accuracy :",accuracy_score(y2,p))
# Out:
# Accuracy : 0.9822222222222222

# %% [markdown]
# Experiment 4 – Overfitting

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
x=np.sort(np.random.rand(30))
y=np.cos(1.5*np.pi*x)
plt.plot(x,y)
plt.title("Overfitting")
plt.show()

# %% [markdown]
# Experiment 5 – Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
iris=load_iris()
data=pd.DataFrame(data=iris.data,
columns=iris.feature_names)
X=data[['sepal length (cm)']]
y=data['sepal width (cm)']
X_train,X_test,y_train,y_test=train_test_split(
X,y,test_size=0.3,random_state=42)
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
mse=mean_squared_error(y_test,y_pred)
print(f'Mean Squared Error on test set: {mse:.2f}')
new_sample=pd.DataFrame([[5]],
columns=['sepal length (cm)'])
predicted_width=model.predict(new_sample)
print(f'The predicted sepal width for sepal length [[5]] is {predicted_width[0]:.2f} cm')
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred)
plt.title("Linear Regression")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()
# Out:
# Mean Squared Error on test set: 0.23
# The predicted sepal width for sepal length [[5]] is 3.02 cm

# %% [markdown]
# Experiment 6 – KNN using Wine Dataset

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
x,y=load_wine(return_X_y=True)
x1,x2,y1,y2=train_test_split(
x,y,test_size=0.3,random_state=1)
m=KNeighborsClassifier(n_neighbors=5)
m.fit(x1,y1)
p=m.predict(x2)
cm=confusion_matrix(y2,p)
sns.heatmap(cm,annot=True,fmt='g')
plt.show()
print("accuracy:",accuracy_score(y2,p))
# Out:
# accuracy: 0.7037037037037037

# %% [markdown]
# Experiment 7 – Logistic Regression Sigmoid Function

# %%
import numpy as np
import matplotlib.pyplot as plt
def sigmoid(z):
    return 1/(1+np.exp(-z))
x=np.arange(-5,5,0.1)
plt.plot(x,sigmoid(x))
plt.title("Sigmoid Function")
plt.show()

# %% [markdown]
# Experiment 8 – KNN using Iris Dataset

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import *
import seaborn as sns
import matplotlib.pyplot as plt
x,y=load_iris(return_X_y=True)
x1,x2,y1,y2=train_test_split(
x,y,test_size=0.3,random_state=1)
m=KNeighborsClassifier(5)
m.fit(x1,y1)
p=m.predict(x2)
sns.heatmap(confusion_matrix(y2,p),annot=True,fmt='g')
plt.show()
print("accuracy:",accuracy_score(y2,p))
# Out:
# accuracy: 0.9777777777777777

# %% [markdown]
# Experiment 9 – Naïve Bayes

# %%
from sklearn.datasets import *
from sklearn.model_selection import *
from sklearn.naive_bayes import *
from sklearn.metrics import *
import seaborn as s
import matplotlib.pyplot as p
x,y=load_iris(return_X_y=True)
a,b,c,d=train_test_split(
x,y,test_size=0.3,random_state=42)
m=GaussianNB()
m.fit(a,c)
q=m.predict(b)
s.heatmap(confusion_matrix(d,q),annot=True,fmt='g')
plt.show()
print("accuracy:",accuracy_score(d,q))
# Out:
# accuracy: 0.9777777777777777

# %% [markdown]
# Experiment 10 – Logistic Regression using Iris Dataset

# %%
from sklearn.datasets import *
from sklearn.model_selection import *
from sklearn.linear_model import *
from sklearn.metrics import *
import seaborn as s
import matplotlib.pyplot as p
x,y=load_iris(return_X_y=True)
a,b,c,d=train_test_split(
x,y,test_size=0.2,random_state=1)
m=LogisticRegression(max_iter=200)
m.fit(a,c)
q=m.predict(b)
s.heatmap(confusion_matrix(d,q),annot=True,fmt='g')
plt.show()
print("accuracy:",accuracy_score(d,q))
# Out:
# accuracy: 0.9666666666666667
